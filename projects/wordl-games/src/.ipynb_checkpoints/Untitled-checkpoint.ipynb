# %%
with open('./five_word_ranked.wordlist', 'r') as f:
#     l = []
    
    print("let freq_score : { [word: string]: number } = {", end="")
#     for line in l:
        
    for line in f.readlines():
        cur_line = line.split()
        print(f"'{cur_line[0]}' : {int(cur_line[1])}, ", end="")
    
    print("}")
# Out:
# let freq_score : { [word: string]: number } = {about : 96471, other : 76948, which : 63739, their : 61564, there : 55140, first : 45467, would : 45033, these : 42545, click : 42210, price : 39450, state : 35632, email : 34912, world : 33967, music : 32559, after : 29329, video : 28736, where : 28347, books : 27344, links : 26732, years : 26568, order : 26473, items : 25991, group : 25310, under : 24637, games : 24058, could : 23774, great : 23709, hotel : 23433, store : 22908, terms : 21839, right : 21517, local : 21291, those : 21234, using : 21189, phone : 20182, forum : 20012, based : 19849, black : 19242, check : 19227, index : 19096, being : 19092, women : 19072, today : 18816, south : 18762, pages : 18402, found : 18245, house : 18190, photo : 17861, power : 17819, while : 17788, three : 17569, total : 17509, place : 17377, think : 17132, north : 17128, posts : 17051, media : 17020, water : 16921, since : 16853, guide : 16780, board : 16700, white : 16503, small : 16386, times 
# ...
